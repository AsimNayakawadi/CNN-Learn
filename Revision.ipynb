# %% [markdown]
# ## Revision

# %% [markdown]
# ### Problem 1 — List comprehension

# %% [markdown]
# Make a new list with only words that have more than 3 letters.

# %%
words = ["hello", "world", "python", "is", "fun"]

# %%
res = [f for f in words if len(f) > 3]
print(res)
# Out:
# ['hello', 'world', 'python']

# %% [markdown]
# ## Problem 2 — List comprehension

# %% [markdown]
# Make a new list where every number is multiplied by 2, but only if the number is greater than 6.

# %%
numbers = [3, 7, 12, 5, 18, 21, 4, 9]

# %%
res2 = [n*2 for n in numbers if n>6]
print(res2)
# Out:
# [14, 24, 36, 42, 18]

# %% [markdown]
# ## Problem 3 — List comprehension

# %% [markdown]
# Keep only files that start with "img" and replace .png with ".jpg" for each one.

# %%
files = ["img_001.png", "mask_001.png", "img_002.png", "mask_002.png", "img_003.png"]

# %%
res3 = [ f.replace(".png",".jpg") for f in files if f.startswith("img")]
print(res3)
# Out:
# ['img_001.jpg', 'img_002.jpg', 'img_003.jpg']

# %% [markdown]
# ## Problem 4 — First class

# %% [markdown]
# ### Write a class called Box that:
#
# Takes one argument items (a list) in __init__ and stores it
#
# Has a method count() that returns how many items are in the box
#
# Has a method first() that returns the first item

# %%
class Box():
    def __init__(self, items):
        self.items = items

    def count(self):
        return len(self.items)

    def first(self):
        return self.items[0]

# %%
b = Box(["apple", "banana", "cherry"])
print(b.count())   # 3
print(b.first())   # apple
# Out:
# 3
# apple

# %% [markdown]
# ### Lets build class from basics

# %%
class Remote:
    pass

# %%
r = Remote()
print(r)

# %%
r.channel = 5 # just attach data directly onto the object
print(r.channel)
# Out:
# 5

# %%
class Remote:
    def __init__(self, channel):
        self.channel = channel

r = Remote(5)
print(r.channel)
# Out:
# 5

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 r1.channel = 100
#       2 print(r1.channel)   # what happens here?
#       3 print(r2.channel)   # and here — did it change?
#
# NameError: name 'r1' is not defined

# %%
class Remote:
    def __init__(self, channel):
        self.channel = channel

r1 = Remote(5)
r2 = Remote(9)

print(r1.channel)
print(r2.channel)
# Out:
# 5
# 9

# %%
r1.channel = 100
print(r1.channel)   # what happens here?
print(r2.channel)   # and here — did it change?
# Out:
# 100
# 9

# %%
class Remote:
    def __init__(self, channel):
        self.channel = channel

    def show_channel(self):
        print(f"Current channel: {self.channel}")

r1 = Remote(5)
r1.show_channel()
# Out:
# Current channel: 5
